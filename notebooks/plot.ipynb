# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
D = pd.read_csv('../makeaffine.csv')

# %%
D2 = pd.read_csv('../constructor.csv')

# %%
D['type'] = 'makeAffine()'
D2['type'] = 'Identity()'
D = pd.concat([D, D2])

# %%
D= D[D['warmup'] == 100]
D['time per construction'] = D['time'] / D['runs']

# %%
sns.boxplot(D, x='type', y='time per construction', hue='type');
